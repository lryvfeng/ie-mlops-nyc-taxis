# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-3.5.1-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==3.5.1 (from mlflow)
#   Using cached mlflow_skinny-3.5.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.1 (from mlflow)
#   Using cached mlflow_tracing-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (3.1.0)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.17.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (44.0.1)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (2.1.3)
# Requirement already satisfied: pandas<3 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (2.3.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow) (2.0.39)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading databricks_sdk-0.70.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading fastapi-0.120.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.5.1->mlflow) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==3.5.1->mlflow)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.12 in /Users/flr/anaconda3/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading google_auth-2.42.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Collecting starlette<0.50.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.5.1->mlflow)
#   Downloading starlette-0.49.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.5.1->mlflow)
#   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /Users/flr/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/flr/anaconda3/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.2.0)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/flr/anaconda3/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in /Users/flr/anaconda3/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/flr/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flr/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/flr/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/flr/anaconda3/lib/python3.13/site-packages (from starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/flr/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /Users/flr/anaconda3/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.5.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/flr/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/flr/anaconda3/lib/python3.13/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)
# Downloading mlflow-3.5.1-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 226.4 kB/s eta 0:00:0000:0100:02
# Downloading mlflow_skinny-3.5.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 142.5 kB/s eta 0:00:00a 0:00:02
# Downloading mlflow_tracing-3.5.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 257.6 kB/s eta 0:00:00a 0:00:01
# Downloading alembic-1.17.1-py3-none-any.whl (247 kB)
# Downloading databricks_sdk-0.70.0-py3-none-any.whl (752 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.6/752.6 kB 662.0 kB/s eta 0:00:00a 0:00:01
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.120.1-py3-none-any.whl (108 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading google_auth-2.42.0-py2.py3-none-any.whl (222 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.49.1-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.3-py3-none-any.whl (5.5 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: uvicorn, sqlparse, rsa, opentelemetry-proto, Mako, gunicorn, graphql-core, annotated-doc, starlette, opentelemetry-api, graphql-relay, google-auth, docker, alembic, opentelemetry-semantic-conventions, graphene, Flask-CORS, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [mlflow]22/23 [mlflow]skinny]]c-conventions]
# Successfully installed Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.1 annotated-doc-0.0.3 databricks-sdk-0.70.0 docker-7.1.0 fastapi-0.120.1 google-auth-2.42.0 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-3.5.1 mlflow-skinny-3.5.1 mlflow-tracing-3.5.1 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 rsa-4.9.1 sqlparse-0.5.3 starlette-0.49.1 uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///Users/flr/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/flr/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1761735194185, experiment_id='0', last_update_time=1761735194185, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# 2025/10/29 11:53:21 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# Logged run for LogisticRegression, accuracy=0.973
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/flr/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/834530485245064899', creation_time=1761735201471, experiment_id='834530485245064899', last_update_time=1761735201471, lifecycle_stage='active', name='my-experiment-1', tags={'mlflow.experimentKind': 'custom_model_development'}>,
#  <Experiment: artifact_location='file:///Users/flr/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1761735194185, experiment_id='0', last_update_time=1761735194185, lifecycle_stage='active', name='Default', tags={}>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# ERROR:    [Errno 48] Address already in use

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
